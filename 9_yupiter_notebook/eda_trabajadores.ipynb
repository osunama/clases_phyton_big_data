# %%
import pandas as pd

# %% [markdown]
# ### Leer y sacar por pantalla los dtos de excel
# Imprimer las primera filas una vez cargado

# %%
#cargar archivo excel
df= pd.read_excel('./data/empleados.xlsx')

#mostrar las primeras filas
df.head(3)
# Out:
#    id        nombre         apellidos           correo departamento
# 0   1  Juan Antonio     Pérez Jarillo     jj@gmail.com   Desarrollo
# 1   2      Almudena  González Camuñas   almu@gmail.com     Finanzas
# 2   3         Marta   Rodriguez Lopez  marta@gmail.com    Marketing
