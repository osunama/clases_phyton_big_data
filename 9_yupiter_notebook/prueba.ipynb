# %%
import pandas as pd

# %% [markdown]
# # Titulo Notebook
# Este explicación del código

# %%
numero_a = 10
numero_b = 5

def sumar(a,b):
    return a+ b
resultado= sumar(numero_a, numero_b)

# %% [markdown]
# # Más explicaciones
# resultado doble

# %%
doble = resultado * 2
print(doble)
# Out:
# 30

# %%
lista = [1,2,3,4,5]
df = pd.DataFrame(lista)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
